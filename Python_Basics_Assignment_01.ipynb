# %%
#Question 1: Basic Print
print("Welcome to Python Programming!")
print("I am learning the basics.")
# Out:
# Welcome to Python Programming!
# I am learning the basics.

# %%
#Question 2: Print with Variables
name = "MD. MAHEDI HASAN"
age = 21

print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is MD. MAHEDI HASAN and I am 21 years old.

# %%
#Question 3: User Input
name = input("Enter Name")
fav_lang = input("What is your favourite programming language")

print(f"Hello {name}, your favourite language is {fav_lang}")
# Out:
# Enter NameMD. MAHEDI HASAN
# What is your favourite programming languagePython
# Hello MD. MAHEDI HASAN, your favourite language is Python

# %%
#Question 4: Type Casting (String to Integer)
num1 = int(input("Enter First Number"))
num2 = int(input("Enter Second Number"))

sum = num1 + num2

print(f"The sum is {sum}")
# Out:
# Enter First Number5
# Enter Second Number2
# The sum is 7

# %%
#Question 5: Simple Calculator

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print("Addition:", num1 + num2)
print("Subtraction:", num1 - num2)
print("Multiplication:", num1 * num2)
# Out:
# Enter first number: 2
# Enter second number: 5
# Addition: 7
# Subtraction: -3
# Multiplication: 10

# %%
#Question 5: Simple Calculator using if else(this is how tahmid sir taught)

num1 = int(input("Enter First Number"))
num2 = int(input("Enter Second Number"))
op = (input("Enter the operator"))

if op == "+":
  print(f"Addition is {num1 + num2}")
elif op == "-":
  print(f"Substration is {num1 - num2}")
elif op == "*":
  print(f"Multiplication is {num1 * num2}")
else:
  print("invalid oprator")
# Out:
# Enter First Number4
# Enter Second Number6
# Enter the operator*
# Multiplication is 24
